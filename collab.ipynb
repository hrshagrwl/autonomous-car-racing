# %%
# !pip install gym
# !pip install gym[Box2D]
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.2.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.16.2)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2019.3.9)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Requirement already satisfied: gym[Box2D] in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (1.2.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (1.16.2)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (1.3.2)
# Requirement already satisfied: box2d-py>=2.3.5 in /usr/local/lib/python3.6/dist-packages (from gym[Box2D]) (2.3.8)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[Box2D]) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[Box2D]) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[Box2D]) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[Box2D]) (1.22)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym[Box2D]) (0.16.0)

# %%
# !apt-get install python-opengl -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 6 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 1s (693 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 131304 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...

# %%
# !apt install xvfb -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 6 not upgraded.
# Need to get 783 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.2 [783 kB]
# Fetched 783 kB in 1s (1,005 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 133659 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.2_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.2) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !pip install pyvirtualdisplay
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/39/37/f285403a09cc261c56b6574baace1bdcf4b8c7428c8a7239cbba137bc0eb/PyVirtualDisplay-0.2.1.tar.gz
# Collecting EasyProcess (from pyvirtualdisplay)
#   Downloading https://files.pythonhosted.org/packages/45/3a/4eecc0c7995a13a64739bbedc0d3691fc574245b7e79cff81905aa0c2b38/EasyProcess-0.2.5.tar.gz
# Building wheels for collected packages: pyvirtualdisplay, EasyProcess
#   Building wheel for pyvirtualdisplay (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/d1/8c/16/1c64227974ae29c687e4cc30fd691d5c0fd40f54446dde99da
#   Building wheel for EasyProcess (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/41/22/19/af15ef6264c58b625a82641ed7483ad05e258fbd8925505227
# Successfully built pyvirtualdisplay EasyProcess
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.2.5 pyvirtualdisplay-0.2.1

# %%
# !pip install piglet
# Out:
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/86/f6/ef278239ebe525466ea51a7dd9d6d3211d197ac4b4abc76e17cdd419f69c/piglet-0.4.4.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 3.0MB/s
# Collecting Parsley (from piglet)
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 8.3MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from piglet) (19.1.0)
# Collecting astunparse (from piglet)
#   Downloading https://files.pythonhosted.org/packages/2e/37/5dd0dd89b87bb5f0f32a7e775458412c52d78f230ab8d0c65df6aabc4479/astunparse-1.6.2-py2.py3-none-any.whl
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet) (1.1.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (1.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (0.33.1)
# Building wheels for collected packages: piglet
#   Building wheel for piglet (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/c7/59/a5/5bd1a35a4a4596714c4c7925a1751e7b1580b6ced363fd7969
# Successfully built piglet
# Installing collected packages: Parsley, astunparse, piglet
# Successfully installed Parsley-1.3 astunparse-1.6.2 piglet-0.4.4

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1013'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1013'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %% [markdown]
# **OpenAI Gym**
#
# We're gonna spend several next weeks learning algorithms that solve decision processes. We are then in need of some interesting decision problems to test our algorithms.
#
# That's where OpenAI gym comes into play. It's a python library that wraps many classical decision problems including robot control, videogames and board games.
#
# So here's how it works:

# %%
import gym
env = gym.make("CarRacing-v0")

import itertools as it
from agent import DQNAgent

# %%
import torch
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# reset() - reset environment to initial state, return first observation
#
# render() - show current environment state (a more colorful version :) )
#
# step(a) - commit action a and return (new observation, reward, is done, info)

# %%
agent = DQNAgent(env)
agent.render = False
# Out:
# ---------- Initializing -----------
# Action Map ->  12
# ---------- Model ---------
# DQN(
#   (conv1): Conv2d(1, 8, kernel_size=(4, 4), stride=(2, 2))
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=29584, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=12, bias=True)
# )

# %%
scores = []
frames_in_episodes = []
for i in range(10000):
    score, frames = agent.play_episode()
    scores.append(score)
    frames_in_episodes.append(frames)
    
    print(i, score, frames)
    if i % 500 == 0:
        torch.save(agent.training_model.state_dict(), 'checkpoint.pth')
# Out:
# Track generation: 1202..1517 -> 315-tiles track
# Epsilon decay steps ----> 0
# 0 -11.27643312101908 24
# Track generation: 954..1201 -> 247-tiles track
# Epsilon decay steps ----> 24
# 1 2.7853658536584796 46
# Track generation: 1284..1618 -> 334-tiles track
# Epsilon decay steps ----> 70
# 2 -2.5729729729730337 32
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 102
# 3 -4.224475524475569 29
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 131
# 4 -8.320979020978985 31
# Track generation: 1131..1418 -> 287-tiles track
# Epsilon decay steps ----> 162
# 5 0.8650349650348907 47
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 209
# 6 -7.720979020978996 29
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 238
# 7 5.671232876712242 40
# Track generation: 957..1208 -> 251-tiles track
# Epsilon decay steps ----> 278
# 8 -1.0000000000000568 30
# Track generation: 1218..1526 -> 308-tiles track
# Epsilon decay steps ----> 308
# 9 4.730618892508076 37
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 345
# 10 -5.124475524475551 32
# Track generation: 1113..1395 -> 282-tiles track
# Epsilon decay steps ----> 377
# 11 -6.447686832740214 26
# Track generation: 1167..1463 -> 296-tiles track
# Epsilon decay steps ----> 403
# 12 -1.881355932203462 30
# Track generation: 1059..1331 -> 272-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1160..1453 -> 293-tiles track
# Epsilon decay steps ----> 433
# 13 13.720547945205382 36
# Track generation: 1012..1268 -> 256-tiles track
# Epsilon decay steps ----> 469
# 14 7.237254901960622 53
# Track generation: 1252..1569 -> 317-tiles track
# Epsilon decay steps ----> 522
# 15 -9.712658227848069 29
# Track generation: 1024..1288 -> 264-tiles track
# Epsilon decay steps ----> 551
# 16 4.020532319391567 34
# Track generation: 1062..1331 -> 269-tiles track
# Epsilon decay steps ----> 585
# 17 15.90746268656708 42
# Track generation: 1068..1339 -> 271-tiles track
# Epsilon decay steps ----> 627
# 18 12.74444444444434 39
# Track generation: 1117..1400 -> 283-tiles track
# Epsilon decay steps ----> 666
# 19 16.445390070921874 44
# Track generation: 1303..1633 -> 330-tiles track
# Epsilon decay steps ----> 710
# 20 -9.562917933130668 26
# Track generation: 1033..1295 -> 262-tiles track
# Epsilon decay steps ----> 736
# 21 7.814176245210643 35
# Track generation: 1345..1685 -> 340-tiles track
# Epsilon decay steps ----> 771
# 22 20.447197640117864 52
# Track generation: 939..1183 -> 244-tiles track
# Epsilon decay steps ----> 823
# 23 7.4370370370369585 32
# Track generation: 1045..1311 -> 266-tiles track
# Epsilon decay steps ----> 855
# 24 3.7622641509433343 34
# Track generation: 1419..1778 -> 359-tiles track
# Epsilon decay steps ----> 889
# 25 28.345810055865805 53
# Track generation: 1136..1424 -> 288-tiles track
# Epsilon decay steps ----> 942
# 26 -4.309756097561026 29
# Track generation: 1194..1496 -> 302-tiles track
# Epsilon decay steps ----> 971
# 27 7.567109634551418 41
# Track generation: 1087..1363 -> 276-tiles track
# Epsilon decay steps ----> 1012
# 28 -6.881818181818172 29
# Track generation: 1240..1554 -> 314-tiles track
# Epsilon decay steps ----> 1041
# 29 -3.1408945686901433 29
# Track generation: 1065..1335 -> 270-tiles track
# Epsilon decay steps ----> 1070
# 30 -8.912639405204432 25
# Track generation: 1112..1401 -> 289-tiles track
# Epsilon decay steps ----> 1095
# 31 -9.838888888888862 24
# Track generation: 1215..1523 -> 308-tiles track
# Epsilon decay steps ----> 1119
# 32 -5.898697068403916 29
# Track generation: 1252..1569 -> 317-tiles track
# Epsilon decay steps ----> 1148
# 33 -6.5481012658227815 29
# Track generation: 1207..1512 -> 305-tiles track
# Epsilon decay steps ----> 1177
# 34 18.2315789473683 48
# Track generation: 1111..1393 -> 282-tiles track
# Epsilon decay steps ----> 1225
# 35 -3.788967971530301 29
# Track generation: 1244..1559 -> 315-tiles track
# Epsilon decay steps ----> 1254
# 36 -8.6917197452229 26
# Track generation: 1065..1342 -> 277-tiles track
# Epsilon decay steps ----> 1280
# 37 2.108695652173836 35
# Track generation: 1104..1384 -> 280-tiles track
# Epsilon decay steps ----> 1315
# 38 -0.3261648745520276 30
# Track generation: 1133..1428 -> 295-tiles track
# Epsilon decay steps ----> 1345
# 39 7.214965986394482 34
# Track generation: 1159..1453 -> 294-tiles track
# Epsilon decay steps ----> 1379
# 40 -4.809215017064879 29
# Track generation: 976..1224 -> 248-tiles track
# Epsilon decay steps ----> 1408
# 41 20.631578947368325 40
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1092..1369 -> 277-tiles track
# Epsilon decay steps ----> 1448
# 42 5.731884057970937 35
# Track generation: 1035..1298 -> 263-tiles track
# Epsilon decay steps ----> 1483
# 43 41.03587786259534 51
# Track generation: 1007..1265 -> 258-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1089..1365 -> 276-tiles track
# Epsilon decay steps ----> 1534
# 44 7.999999999999893 40
# Track generation: 1155..1448 -> 293-tiles track
# Epsilon decay steps ----> 1574
# 45 4.346575342465673 33
# Track generation: 1216..1524 -> 308-tiles track
# Epsilon decay steps ----> 1607
# 46 -6.798697068403895 32
# Track generation: 1084..1359 -> 275-tiles track
# Epsilon decay steps ----> 1639
# 47 -3.7525547445256073 31
# Track generation: 1207..1522 -> 315-tiles track
# Epsilon decay steps ----> 1670
# 48 -4.122292993630619 32
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 1702
# 49 -10.77759197324412 25
# Track generation: 1265..1586 -> 321-tiles track
# Epsilon decay steps ----> 1727
# 50 -5.500000000000009 35
# Track generation: 1134..1421 -> 287-tiles track
# Epsilon decay steps ----> 1762
# 51 -1.3279720279720877 31
# Track generation: 1071..1349 -> 278-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1091..1373 -> 282-tiles track
# Epsilon decay steps ----> 1793
# 52 5.08718861209956 35
# Track generation: 1279..1603 -> 324-tiles track
# Epsilon decay steps ----> 1828
# 53 -9.824148606811113 28
# Track generation: 1069..1341 -> 272-tiles track
# Epsilon decay steps ----> 1856
# 54 10.390405904058973 34
# Track generation: 1280..1601 -> 321-tiles track
# Epsilon decay steps ----> 1890
# 55 -11.874999999999972 25
# Track generation: 1122..1414 -> 292-tiles track
# Epsilon decay steps ----> 1915
# 56 -1.8085910652921662 31
# Track generation: 1164..1459 -> 295-tiles track
# Epsilon decay steps ----> 1946
# 57 28.624489795918258 42
# Track generation: 1071..1343 -> 272-tiles track
# Epsilon decay steps ----> 1988
# 58 38.59077490774887 63
# Track generation: 1157..1450 -> 293-tiles track
# Epsilon decay steps ----> 2051
# 59 34.69315068493139 46
# Track generation: 1056..1324 -> 268-tiles track
# Epsilon decay steps ----> 2097
# 60 47.097003745318545 51
# Track generation: 1122..1403 -> 281-tiles track
# Epsilon decay steps ----> 2148
# 61 14.428571428571331 40
# Track generation: 1252..1569 -> 317-tiles track
# Epsilon decay steps ----> 2188
# 62 16.06835443037965 38
# Track generation: 1088..1364 -> 276-tiles track
# Epsilon decay steps ----> 2226
# 63 -6.581818181818177 28
# Track generation: 918..1155 -> 237-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1232..1544 -> 312-tiles track
# Epsilon decay steps ----> 2254
# 64 -0.36109324758848516 31
# Track generation: 1057..1325 -> 268-tiles track
# Epsilon decay steps ----> 2285
# 65 54.58764044943844 51
# Track generation: 1039..1307 -> 268-tiles track
# Epsilon decay steps ----> 2336
# 66 9.49850187265909 39
# Track generation: 1211..1518 -> 307-tiles track
# Epsilon decay steps ----> 2375
# 67 46.09934640522897 52
# Track generation: 1097..1375 -> 278-tiles track
# Epsilon decay steps ----> 2427
# 68 13.731407942238178 44
# Track generation: 1060..1329 -> 269-tiles track
# Epsilon decay steps ----> 2471
# 69 -6.611940298507452 30
# Track generation: 1102..1389 -> 287-tiles track
# Epsilon decay steps ----> 2501
# 70 -5.724475524475528 34
# Track generation: 1015..1273 -> 258-tiles track
# Epsilon decay steps ----> 2535
# 71 -4.753696498054508 27
# Track generation: 1191..1493 -> 302-tiles track
# Epsilon decay steps ----> 2562
# 72 3.622591362126183 32
# Track generation: 1077..1355 -> 278-tiles track
# Epsilon decay steps ----> 2594
# 73 -4.329241877256363 32
# Track generation: 1055..1331 -> 276-tiles track
# Epsilon decay steps ----> 2626
# 74 -6.58181818181818 28
# Track generation: 1142..1432 -> 290-tiles track
# Epsilon decay steps ----> 2654
# 75 -4.178546712802813 28
# Track generation: 1147..1437 -> 290-tiles track
# Epsilon decay steps ----> 2682
# 76 -7.638754325259491 28
# Track generation: 1026..1286 -> 260-tiles track
# Epsilon decay steps ----> 2710
# 77 -7.894980694980671 24
# Track generation: 1060..1329 -> 269-tiles track
# Epsilon decay steps ----> 2734
# 78 6.213432835820814 37
# Track generation: 1112..1397 -> 285-tiles track
# Epsilon decay steps ----> 2771
# 79 59.69154929577489 63
# Track generation: 1163..1458 -> 295-tiles track
# Epsilon decay steps ----> 2834
# 80 -4.590476190476233 28
# Track generation: 1255..1571 -> 316-tiles track
# Epsilon decay steps ----> 2862
# 81 -6.777777777777766 30
# Track generation: 1151..1452 -> 301-tiles track
# Epsilon decay steps ----> 2892
# 82 1.9333333333332803 38
# Track generation: 1049..1322 -> 273-tiles track
# Epsilon decay steps ----> 2930
# 83 -1.6882352941177103 37
# Track generation: 1211..1518 -> 307-tiles track
# Epsilon decay steps ----> 2967
# 84 20.287581699346312 40
# Track generation: 1191..1497 -> 306-tiles track
# Epsilon decay steps ----> 3007
# 85 -11.40655737704915 26
# Track generation: 1221..1530 -> 309-tiles track
# Epsilon decay steps ----> 3033
# 86 -10.966233766233739 24
# Track generation: 1071..1343 -> 272-tiles track
# Epsilon decay steps ----> 3057
# 87 12.58044280442796 39
# Track generation: 1076..1355 -> 279-tiles track
# Epsilon decay steps ----> 3096
# 88 -5.020143884892107 34
# Track generation: 1227..1538 -> 311-tiles track
# Epsilon decay steps ----> 3130
# 89 -4.993548387096821 36
# Track generation: 1266..1586 -> 320-tiles track
# Epsilon decay steps ----> 3166
# 90 4.7175548589341005 43
# Track generation: 1323..1658 -> 335-tiles track
# Epsilon decay steps ----> 3209
# 91 -2.6538922155689235 32
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1231..1543 -> 312-tiles track
# Epsilon decay steps ----> 3241
# 92 45.13215434083635 83
# Track generation: 1196..1499 -> 303-tiles track
# Epsilon decay steps ----> 3324
# 93 -4.609933774834481 37
# Track generation: 970..1216 -> 246-tiles track
# Epsilon decay steps ----> 3361
# 94 1.5530612244897384 37
# Track generation: 1066..1339 -> 273-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1104..1384 -> 280-tiles track
# Epsilon decay steps ----> 3398
# 95 -9.278853046594955 24
# Track generation: 1051..1318 -> 267-tiles track
# Epsilon decay steps ----> 3422
# 96 6.493984962405939 37
# Track generation: 1166..1468 -> 302-tiles track
# Epsilon decay steps ----> 3459
# 97 64.39003322259173 62
# Track generation: 1388..1739 -> 351-tiles track
# Epsilon decay steps ----> 3521
# 98 -7.942857142857102 36
# Track generation: 1456..1824 -> 368-tiles track
# Epsilon decay steps ----> 3557
# 99 -9.026430517711141 27
# Track generation: 1120..1410 -> 290-tiles track
# Epsilon decay steps ----> 3584
# 100 10.122491349480896 38
# Track generation: 1235..1548 -> 313-tiles track
# Epsilon decay steps ----> 3622
# 101 -2.253846153846201 37
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 3659
# 102 -7.552054794520528 27
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 3686
# 103 -8.129729729729696 28
# Track generation: 1163..1458 -> 295-tiles track
# Epsilon decay steps ----> 3714
# 104 -4.890476190476228 29
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 3743
# 105 5.989297658862807 36
# Track generation: 1050..1317 -> 267-tiles track
# Epsilon decay steps ----> 3779
# 106 -5.543609022556401 27
# Track generation: 1108..1389 -> 281-tiles track
# Epsilon decay steps ----> 3806
# 107 -1.0285714285714924 32
# Track generation: 1083..1363 -> 280-tiles track
# Epsilon decay steps ----> 3838
# 108 2.3580645161289553 33
# Track generation: 1148..1439 -> 291-tiles track
# Epsilon decay steps ----> 3871
# 109 1.1344827586206137 33
# Track generation: 1075..1348 -> 273-tiles track
# Epsilon decay steps ----> 3904
# 110 13.917647058823448 34
# Track generation: 1215..1523 -> 308-tiles track
# Epsilon decay steps ----> 3938
# 111 5.287947882736049 46
# Track generation: 795..1003 -> 208-tiles track
# Epsilon decay steps ----> 3984
# 112 3.3164251207728626 35
# Track generation: 1187..1488 -> 301-tiles track
# Epsilon decay steps ----> 4019
# 113 -2.333333333333396 30
# Track generation: 1099..1378 -> 279-tiles track
# Epsilon decay steps ----> 4049
# 114 -3.5201438848921462 29
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 4078
# 115 -5.051351351351382 29
# Track generation: 1260..1579 -> 319-tiles track
# Epsilon decay steps ----> 4107
# 116 -11.776729559748398 25
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 4132
# 117 6.284210526315725 33
# Track generation: 1166..1464 -> 298-tiles track
# Epsilon decay steps ----> 4165
# 118 0.10303030303024485 34
# Track generation: 1206..1512 -> 306-tiles track
# Epsilon decay steps ----> 4199
# 119 -2.7704918032787376 30
# Track generation: 1144..1434 -> 290-tiles track
# Epsilon decay steps ----> 4229
# 120 8.02249134948088 45
# Track generation: 1327..1663 -> 336-tiles track
# Epsilon decay steps ----> 4274
# 121 -12.874626865671612 26
# Track generation: 1323..1658 -> 335-tiles track
# Epsilon decay steps ----> 4300
# 122 -0.2598802395210278 34
# Track generation: 1148..1439 -> 291-tiles track
# Epsilon decay steps ----> 4334
# 123 -1.7137931034483351 31
# Track generation: 1300..1629 -> 329-tiles track
# Epsilon decay steps ----> 4365
# 124 7.934146341463318 39
# Track generation: 1408..1764 -> 356-tiles track
# Epsilon decay steps ----> 4404
# 125 0.48591549295768033 35
# Track generation: 1301..1629 -> 328-tiles track
# Epsilon decay steps ----> 4439
# 126 -0.5189602446483761 37
# Track generation: 1183..1483 -> 300-tiles track
# Epsilon decay steps ----> 4476
# 127 -6.488628762541797 33
# Track generation: 1080..1360 -> 280-tiles track
# Epsilon decay steps ----> 4509
# 128 21.16344086021494 42
# Track generation: 1077..1354 -> 277-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1182..1482 -> 300-tiles track
# Epsilon decay steps ----> 4551
# 129 -5.588628762541818 30
# Track generation: 1315..1648 -> 333-tiles track
# Epsilon decay steps ----> 4581
# 130 -10.027710843373463 27
# Track generation: 1199..1503 -> 304-tiles track
# Epsilon decay steps ----> 4608
# 131 0.4029702970296398 31
# Track generation: 1115..1398 -> 283-tiles track
# Epsilon decay steps ----> 4639
# 132 4.660992907801333 36
# Track generation: 1023..1288 -> 265-tiles track
# Epsilon decay steps ----> 4675
# 133 4.378787878787783 45
# Track generation: 1095..1373 -> 278-tiles track
# Epsilon decay steps ----> 4720
# 134 51.34259927797858 51
# Track generation: 1260..1579 -> 319-tiles track
# Epsilon decay steps ----> 4771
# 135 2.5911949685533955 40
# Track generation: 1227..1538 -> 311-tiles track
# Epsilon decay steps ----> 4811
# 136 21.63870967741925 44
# Track generation: 1280..1604 -> 324-tiles track
# Epsilon decay steps ----> 4855
# 137 11.643653250773909 39
# Track generation: 1140..1429 -> 289-tiles track
# Epsilon decay steps ----> 4894
# 138 -1.222222222222289 30
# Track generation: 1157..1451 -> 294-tiles track
# Epsilon decay steps ----> 4924
# 139 -1.6962457337884587 30
# Track generation: 1436..1799 -> 363-tiles track
# Epsilon decay steps ----> 4954
# 140 -6.9005524861878325 30
# Track generation: 1265..1586 -> 321-tiles track
# Epsilon decay steps ----> 4984
# 141 -11.274999999999974 23
# Track generation: 1079..1352 -> 273-tiles track
# Epsilon decay steps ----> 5007
# 142 31.476470588235188 49
# Track generation: 1179..1478 -> 299-tiles track
# Epsilon decay steps ----> 5056
# 143 -5.810067114093965 31
# Track generation: 1033..1302 -> 269-tiles track
# Epsilon decay steps ----> 5087
# 144 -3.7805970149254335 33
# Track generation: 1208..1514 -> 306-tiles track
# Epsilon decay steps ----> 5120
# 145 22.23770491803269 45
# Track generation: 1126..1418 -> 292-tiles track
# Epsilon decay steps ----> 5165
# 146 14.60996563573871 45
# Track generation: 1111..1393 -> 282-tiles track
# Epsilon decay steps ----> 5210
# 147 27.298220640569284 44
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 5254
# 148 5.0892976588628045 39
# Track generation: 1170..1467 -> 297-tiles track
# Epsilon decay steps ----> 5293
# 149 -2.572972972973023 32
# Track generation: 1036..1307 -> 271-tiles track
# Epsilon decay steps ----> 5325
# 150 2.2333333333332597 37
# Track generation: 975..1223 -> 248-tiles track
# Epsilon decay steps ----> 5362
# 151 -6.957085020242909 24
# Track generation: 1095..1373 -> 278-tiles track
# Epsilon decay steps ----> 5386
# 152 -3.4292418772563735 29
# Track generation: 1083..1358 -> 275-tiles track
# Epsilon decay steps ----> 5415
# 153 54.740875912408995 55
# Track generation: 1195..1498 -> 303-tiles track
# Epsilon decay steps ----> 5470
# 154 -6.721192052980117 33
# Track generation: 1098..1376 -> 278-tiles track
# Epsilon decay steps ----> 5503
# 155 7.421299638989048 53
# Track generation: 1288..1614 -> 326-tiles track
# Epsilon decay steps ----> 5556
# 156 -9.638461538461508 27
# Track generation: 1135..1423 -> 288-tiles track
# Epsilon decay steps ----> 5583
# 157 4.343205574912801 35
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 5618
# 158 -6.188628762541805 32
# Track generation: 1118..1402 -> 284-tiles track
# Epsilon decay steps ----> 5650
# 159 -6.36501766784451 37
# Track generation: 1192..1494 -> 302-tiles track
# Epsilon decay steps ----> 5687
# 160 6.0448504983388 35
# Track generation: 1157..1454 -> 297-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 5722
# 161 10.705263157894649 38
# Track generation: 1127..1413 -> 286-tiles track
# Epsilon decay steps ----> 5760
# 162 43.69298245614054 45
# Track generation: 1220..1529 -> 309-tiles track
# Epsilon decay steps ----> 5805
# 163 4.014285714285645 39
# Track generation: 1236..1549 -> 313-tiles track
# Epsilon decay steps ----> 5844
# 164 1.8512820512819772 34
# Track generation: 1081..1362 -> 281-tiles track
# Epsilon decay steps ----> 5878
# 165 -3.7000000000000526 29
# Track generation: 1046..1311 -> 265-tiles track
# Epsilon decay steps ----> 5907
# 166 14.05454545454537 38
# Track generation: 1291..1618 -> 327-tiles track
# Epsilon decay steps ----> 5945
# 167 -1.6926380368098677 31
# Track generation: 1067..1338 -> 271-tiles track
# Epsilon decay steps ----> 5976
# 168 5.637037037036958 38
# Track generation: 1131..1418 -> 287-tiles track
# Epsilon decay steps ----> 6014
# 169 40.12307692307679 56
# Track generation: 1241..1555 -> 314-tiles track
# Epsilon decay steps ----> 6070
# 170 -6.9357827476038185 31
# Track generation: 1285..1616 -> 331-tiles track
# Epsilon decay steps ----> 6101
# 171 -8.387878787878753 32
# Track generation: 1130..1417 -> 287-tiles track
# Epsilon decay steps ----> 6133
# 172 -7.120979020979005 27
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 6160
# 173 -10.676712328767094 26
# Track generation: 1288..1614 -> 326-tiles track
# Epsilon decay steps ----> 6186
# 174 -2.807692307692353 35
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 6221
# 175 -2.2279720279720827 34
# Track generation: 1096..1374 -> 278-tiles track
# Epsilon decay steps ----> 6255
# 176 -3.4292418772563735 29
# Track generation: 1052..1319 -> 267-tiles track
# Epsilon decay steps ----> 6284
# 177 -8.703007518796964 25
# Track generation: 1144..1434 -> 290-tiles track
# Epsilon decay steps ----> 6309
# 178 7.262283737024145 36
# Track generation: 1208..1514 -> 306-tiles track
# Epsilon decay steps ----> 6345
# 179 -6.349180327868849 31
# Track generation: 1005..1268 -> 263-tiles track
# Epsilon decay steps ----> 6376
# 180 -2.8824427480916697 32
# Track generation: 1120..1411 -> 291-tiles track
# Epsilon decay steps ----> 6408
# 181 33.665517241379206 51
# Track generation: 1165..1461 -> 296-tiles track
# Epsilon decay steps ----> 6459
# 182 -1.881355932203455 30
# Track generation: 1245..1560 -> 315-tiles track
# Epsilon decay steps ----> 6489
# 183 1.3471337579617142 35
# Track generation: 1092..1370 -> 278-tiles track
# Epsilon decay steps ----> 6524
# 184 -4.629241877256355 33
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 6557
# 185 -2.3842105263158437 29
# Track generation: 1259..1585 -> 326-tiles track
# Epsilon decay steps ----> 6586
# 186 -9.638461538461508 27
# Track generation: 985..1240 -> 255-tiles track
# Epsilon decay steps ----> 6613
# 187 -2.040944881889814 32
# Track generation: 1226..1537 -> 311-tiles track
# Epsilon decay steps ----> 6645
# 188 -11.070967741935458 24
# Track generation: 1006..1263 -> 257-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1271..1593 -> 322-tiles track
# Epsilon decay steps ----> 6669
# 189 -5.877881619937696 36
# Track generation: 1172..1469 -> 297-tiles track
# Epsilon decay steps ----> 6705
# 190 -4.072972972973016 37
# Track generation: 1311..1652 -> 341-tiles track
# Epsilon decay steps ----> 6742
# 191 -10.752941176470555 28
# Track generation: 1290..1620 -> 330-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1098..1384 -> 286-tiles track
# Epsilon decay steps ----> 6770
# 192 7.196491228070091 38
# Track generation: 1167..1471 -> 304-tiles track
# Epsilon decay steps ----> 6808
# 193 -9.198019801980164 30
# Track generation: 1131..1418 -> 287-tiles track
# Epsilon decay steps ----> 6838
# 194 -7.120979020979005 27
# Track generation: 1043..1313 -> 270-tiles track
# Epsilon decay steps ----> 6865
# 195 -6.095167286245356 28
# Track generation: 1059..1334 -> 275-tiles track
# Epsilon decay steps ----> 6893
# 196 5.996350364963419 35
# Track generation: 967..1219 -> 252-tiles track
# Epsilon decay steps ----> 6928
# 197 26.86095617529871 43
# Track generation: 1231..1543 -> 312-tiles track
# Epsilon decay steps ----> 6971
# 198 1.954340836012797 34
# Track generation: 1288..1614 -> 326-tiles track
# Epsilon decay steps ----> 7005
# 199 8.299999999999919 39
# Track generation: 1063..1333 -> 270-tiles track
# Epsilon decay steps ----> 7044
# 200 12.609665427509213 40
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 7084
# 201 -5.673684210526325 29
# Track generation: 1117..1404 -> 287-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1089..1372 -> 283-tiles track
# Epsilon decay steps ----> 7113
# 202 -1.2312056737589323 32
# Track generation: 1042..1307 -> 265-tiles track
# Epsilon decay steps ----> 7145
# 203 -6.572727272727265 31
# Track generation: 992..1250 -> 258-tiles track
# Epsilon decay steps ----> 7176
# 204 14.992607003890953 39
# Track generation: 1081..1355 -> 274-tiles track
# Epsilon decay steps ----> 7215
# 205 2.767032967032897 34
# Track generation: 1203..1508 -> 305-tiles track
# Epsilon decay steps ----> 7249
# 206 -3.5842105263158395 33
# Track generation: 1232..1544 -> 312-tiles track
# Epsilon decay steps ----> 7282
# 207 -1.8610932475884852 36
# Track generation: 1055..1323 -> 268-tiles track
# Epsilon decay steps ----> 7318
# 208 7.0985018726591065 47
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 7365
# 209 -10.30810810810808 24
# Track generation: 1484..1870 -> 386-tiles track
# Epsilon decay steps ----> 7389
# 210 -0.33376623376626924 47
# Track generation: 1225..1535 -> 310-tiles track
# Epsilon decay steps ----> 7436
# 211 -8.146278317152063 36
# Track generation: 1139..1428 -> 289-tiles track
# Epsilon decay steps ----> 7472
# 212 3.922222222222132 36
# Track generation: 1222..1531 -> 309-tiles track
# Epsilon decay steps ----> 7508
# 213 4.314285714285642 38
# Track generation: 1115..1398 -> 283-tiles track
# Epsilon decay steps ----> 7546
# 214 -10.66950354609926 28
# Track generation: 1032..1298 -> 266-tiles track
# Epsilon decay steps ----> 7574
# 215 27.477358490565926 43
# Track generation: 1095..1373 -> 278-tiles track
# Epsilon decay steps ----> 7617
# 216 39.3122743682309 55
# Track generation: 1059..1337 -> 278-tiles track
# Epsilon decay steps ----> 7672
# 217 0.1808664259927184 29
# Track generation: 1296..1624 -> 328-tiles track
# Epsilon decay steps ----> 7701
# 218 -11.909480122324132 24
# Track generation: 1176..1474 -> 298-tiles track
# Epsilon decay steps ----> 7725
# 219 0.8370370370369073 54
# Track generation: 1073..1352 -> 279-tiles track
# Epsilon decay steps ----> 7779
# 220 -3.220143884892142 28
# Track generation: 1177..1475 -> 298-tiles track
# Epsilon decay steps ----> 7807
# 221 15.738047138047051 38
# Track generation: 1095..1373 -> 278-tiles track
# Epsilon decay steps ----> 7845
# 222 3.190974729241816 31
# Track generation: 1104..1384 -> 280-tiles track
# Epsilon decay steps ----> 7876
# 223 -9.278853046594955 24
# Track generation: 1017..1275 -> 258-tiles track
# Epsilon decay steps ----> 7900
# 224 41.92101167315173 53
# Track generation: 1102..1390 -> 288-tiles track
# Epsilon decay steps ----> 7953
# 225 -2.0254355400697577 33
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 7986
# 226 -6.273684210526316 31
# Track generation: 1182..1481 -> 299-tiles track
# Epsilon decay steps ----> 8017
# 227 -5.810067114093965 31
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 8048
# 228 16.442105263157814 43
# Track generation: 1215..1523 -> 308-tiles track
# Epsilon decay steps ----> 8091
# 229 -8.85602605863189 28
# Track generation: 1186..1487 -> 301-tiles track
# Epsilon decay steps ----> 8119
# 230 -2.9333333333333833 32
# Track generation: 1030..1295 -> 265-tiles track
# Epsilon decay steps ----> 8151
# 231 -2.4848484848485484 30
# Track generation: 1023..1286 -> 263-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1219..1528 -> 309-tiles track
# Epsilon decay steps ----> 8181
# 232 15.201298701298604 45
# Track generation: 1257..1576 -> 319-tiles track
# Epsilon decay steps ----> 8226
# 233 12.02515723270433 40
# Track generation: 1176..1474 -> 298-tiles track
# Epsilon decay steps ----> 8266
# 234 -6.630976430976414 34
# Track generation: 1244..1559 -> 315-tiles track
# Epsilon decay steps ----> 8300
# 235 4.2318471337578885 36
# Track generation: 1111..1400 -> 289-tiles track
# Epsilon decay steps ----> 8336
# 236 10.566666666666578 37
# Track generation: 1153..1446 -> 293-tiles track
# Epsilon decay steps ----> 8373
# 237 4.046575342465669 34
# Track generation: 1172..1469 -> 297-tiles track
# Epsilon decay steps ----> 8407
# 238 -2.27297297297304 31
# Track generation: 1263..1583 -> 320-tiles track
# Epsilon decay steps ----> 8438
# 239 -7.056426332288389 30
# Track generation: 988..1244 -> 256-tiles track
# Epsilon decay steps ----> 8468
# 240 27.723529411764602 37
# Track generation: 1240..1554 -> 314-tiles track
# Epsilon decay steps ----> 8505
# 241 15.518210862619704 52
# Track generation: 1084..1359 -> 275-tiles track
# Epsilon decay steps ----> 8557
# 242 32.19343065693417 45
# Track generation: 1085..1368 -> 283-tiles track
# Epsilon decay steps ----> 8602
# 243 25.883687943262302 48
# Track generation: 1061..1331 -> 270-tiles track
# Epsilon decay steps ----> 8650
# 244 32.21449814126382 49
# Track generation: 1137..1433 -> 296-tiles track
# Epsilon decay steps ----> 8699
# 245 15.75762711864396 39
# Track generation: 1112..1401 -> 289-tiles track
# Epsilon decay steps ----> 8738
# 246 -15.58333333333331 20
# Track generation: 1059..1331 -> 272-tiles track
# Epsilon decay steps ----> 8758
# 247 -6.259778597785978 28
# Track generation: 1185..1485 -> 300-tiles track
# Epsilon decay steps ----> 8786
# 248 -5.888628762541813 31
# Track generation: 1283..1608 -> 325-tiles track
# Epsilon decay steps ----> 8817
# 249 -10.18148148148145 29
# Track generation: 1078..1358 -> 280-tiles track
# Epsilon decay steps ----> 8846
# 250 5.942293906809958 33
# Track generation: 1132..1418 -> 286-tiles track
# Epsilon decay steps ----> 8879
# 251 -1.2298245614035714 31
# Track generation: 1074..1347 -> 273-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1005..1260 -> 255-tiles track
# Epsilon decay steps ----> 8910
# 252 -4.777952755905547 28
# Track generation: 1075..1348 -> 273-tiles track
# Epsilon decay steps ----> 8938
# 253 -6.9411764705882195 30
# Track generation: 1083..1361 -> 278-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1198..1502 -> 304-tiles track
# Epsilon decay steps ----> 8968
# 254 2.5033003300329284 35
# Track generation: 1137..1426 -> 289-tiles track
# Epsilon decay steps ----> 9003
# 255 4.52222222222214 34
# Track generation: 1248..1564 -> 316-tiles track
# Epsilon decay steps ----> 9037
# 256 6.869841269841189 48
# Track generation: 1120..1404 -> 284-tiles track
# Epsilon decay steps ----> 9085
# 257 5.602826855123514 56
# Track generation: 1117..1406 -> 289-tiles track
# Epsilon decay steps ----> 9141
# 258 17.21111111111101 38
# Track generation: 1385..1735 -> 350-tiles track
# Epsilon decay steps ----> 9179
# 259 13.741260744985532 69
# Track generation: 1265..1585 -> 320-tiles track
# Epsilon decay steps ----> 9248
# 260 -6.621630094043869 39
# Track generation: 1290..1617 -> 327-tiles track
# Epsilon decay steps ----> 9287
# 261 5.109815950920179 39
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 9326
# 262 10.105263157894633 40
# Track generation: 1053..1327 -> 274-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1147..1444 -> 297-tiles track
# Epsilon decay steps ----> 9366
# 263 -8.429729729729695 29
# Track generation: 1283..1612 -> 329-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1211..1518 -> 307-tiles track
# Epsilon decay steps ----> 9395
# 264 -4.056209150326847 34
# Track generation: 1121..1405 -> 284-tiles track
# Epsilon decay steps ----> 9429
# 265 -6.898586572438155 27
# Track generation: 1187..1488 -> 301-tiles track
# Epsilon decay steps ----> 9456
# 266 11.966666666666562 49
# Track generation: 1364..1709 -> 345-tiles track
# Epsilon decay steps ----> 9505
# 267 33.174418604651024 65
# Track generation: 1290..1617 -> 327-tiles track
# Epsilon decay steps ----> 9570
# 268 2.6423312883434846 37
# Track generation: 1051..1317 -> 266-tiles track
# Epsilon decay steps ----> 9607
# 269 4.662264150943329 31
# Track generation: 1243..1558 -> 315-tiles track
# Epsilon decay steps ----> 9638
# 270 5.131847133757894 33
# Track generation: 1000..1254 -> 254-tiles track
# Epsilon decay steps ----> 9671
# 271 0.820553359683732 36
# Track generation: 1192..1494 -> 302-tiles track
# Epsilon decay steps ----> 9707
# 272 -8.76644518272422 29
# Track generation: 1091..1368 -> 277-tiles track
# Epsilon decay steps ----> 9736
# 273 5.43188405797094 36
# Track generation: 1126..1412 -> 286-tiles track
# Epsilon decay steps ----> 9772
# 274 40.39298245614025 56
# Track generation: 1158..1452 -> 294-tiles track
# Epsilon decay steps ----> 9828
# 275 31.94641638225246 43
# Track generation: 1161..1455 -> 294-tiles track
# Epsilon decay steps ----> 9871
# 276 -7.322184300341275 26
# Track generation: 1056..1327 -> 271-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1144..1442 -> 298-tiles track
# Epsilon decay steps ----> 9897
# 277 -10.364983164983137 24
# Track generation: 1139..1430 -> 291-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1232..1543 -> 311-tiles track
# Epsilon decay steps ----> 9921
# 278 2.0580645161289652 34
# Track generation: 1254..1572 -> 318-tiles track
# Epsilon decay steps ----> 9955
# 279 -5.26340694006311 35
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 9990
# 280 -5.051351351351382 29
# Track generation: 1212..1518 -> 306-tiles track
# Epsilon decay steps ----> 10019
# 281 -10.806557377049153 24
# Track generation: 1247..1572 -> 325-tiles track
# Epsilon decay steps ----> 10043
# 282 22.055555555555436 45
# Track generation: 1059..1328 -> 269-tiles track
# Epsilon decay steps ----> 10088
# 283 3.2134328358208286 47
# Track generation: 1146..1446 -> 300-tiles track
# Epsilon decay steps ----> 10135
# 284 8.43377926421396 39
# Track generation: 1265..1585 -> 320-tiles track
# Epsilon decay steps ----> 10174
# 285 0.38275862068958233 47
# Track generation: 1072..1344 -> 272-tiles track
# Epsilon decay steps ----> 10221
# 286 5.890405904058952 49
# Track generation: 1296..1624 -> 328-tiles track
# Epsilon decay steps ----> 10270
# 287 -9.451376146788961 26
# Track generation: 1016..1283 -> 267-tiles track
# Epsilon decay steps ----> 10296
# 288 -2.3842105263158473 29
# Track generation: 1323..1658 -> 335-tiles track
# Epsilon decay steps ----> 10325
# 289 28.76826347305378 57
# Track generation: 1185..1485 -> 300-tiles track
# Epsilon decay steps ----> 10382
# 290 32.189632107023286 49
# Track generation: 1226..1536 -> 310-tiles track
# Epsilon decay steps ----> 10431
# 291 -0.17378640776705012 31
# Track generation: 1141..1430 -> 289-tiles track
# Epsilon decay steps ----> 10462
# 292 0.4499999999999318 36
# Track generation: 1277..1600 -> 323-tiles track
# Epsilon decay steps ----> 10498
# 293 8.672670807453336 39
# Track generation: 1103..1383 -> 280-tiles track
# Epsilon decay steps ----> 10537
# 294 -8.994623655913939 35
# Track generation: 1276..1599 -> 323-tiles track
# Epsilon decay steps ----> 10572
# 295 6.467080745341541 36
# Track generation: 1239..1553 -> 314-tiles track
# Epsilon decay steps ----> 10608
# 296 -8.630670926517542 26
# Track generation: 1118..1401 -> 283-tiles track
# Epsilon decay steps ----> 10634
# 297 -8.323404255319115 32
# Track generation: 1064..1344 -> 280-tiles track
# Epsilon decay steps ----> 10666
# 298 -4.510394265233009 32
# Track generation: 1151..1443 -> 292-tiles track
# Epsilon decay steps ----> 10698
# 299 -1.508591065292162 30
# Track generation: 1099..1378 -> 279-tiles track
# Epsilon decay steps ----> 10728
# 300 51.0280575539571 63
# Track generation: 997..1256 -> 259-tiles track
# Epsilon decay steps ----> 10791
# 301 -3.6682170542636108 36
# Track generation: 1038..1304 -> 266-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1240..1560 -> 320-tiles track
# Epsilon decay steps ----> 10827
# 302 13.221943573667602 46
# Track generation: 1080..1363 -> 283-tiles track
# Epsilon decay steps ----> 10873
# 303 -1.2312056737589323 32
# Track generation: 971..1223 -> 252-tiles track
# Epsilon decay steps ----> 10905
# 304 9.040637450199128 36
# Track generation: 1202..1507 -> 305-tiles track
# Epsilon decay steps ----> 10941
# 305 -8.063157894736815 26
# Track generation: 1094..1371 -> 277-tiles track
# Epsilon decay steps ----> 10967
# 306 -6.914492753623152 53
# Track generation: 1085..1363 -> 278-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1216..1524 -> 308-tiles track
# Epsilon decay steps ----> 11020
# 307 -8.556026058631891 27
# Track generation: 1082..1361 -> 279-tiles track
# Epsilon decay steps ----> 11047
# 308 16.8597122302157 45
# Track generation: 1191..1502 -> 311-tiles track
# Epsilon decay steps ----> 11092
# 309 -4.99354838709681 36
# Track generation: 1001..1262 -> 261-tiles track
# Epsilon decay steps ----> 11128
# 310 -0.3307692307692953 37
# Track generation: 1201..1506 -> 305-tiles track
# Epsilon decay steps ----> 11165
# 311 -8.363157894736814 27
# Track generation: 1008..1270 -> 262-tiles track
# Epsilon decay steps ----> 11192
# 312 26.902681992337044 48
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 11240
# 313 18.491489361702023 49
# Track generation: 1150..1443 -> 293-tiles track
# Epsilon decay steps ----> 11289
# 314 1.7712328767122116 53
# Track generation: 1199..1503 -> 304-tiles track
# Epsilon decay steps ----> 11342
# 315 29.206600660065845 56
# Track generation: 1208..1514 -> 306-tiles track
# Epsilon decay steps ----> 11398
# 316 46.66721311475433 51
# Track generation: 1139..1428 -> 289-tiles track
# Epsilon decay steps ----> 11449
# 317 8.76666666666656 43
# Track generation: 1144..1433 -> 289-tiles track
# Epsilon decay steps ----> 11492
# 318 4.994444444444344 44
# Track generation: 1295..1623 -> 328-tiles track
# Epsilon decay steps ----> 11536
# 319 2.839143730886775 36
# Track generation: 1108..1389 -> 281-tiles track
# Epsilon decay steps ----> 11572
# 320 -6.971428571428559 28
# Track generation: 1123..1408 -> 285-tiles track
# Epsilon decay steps ----> 11600
# 321 -4.052112676056396 29
# Track generation: 1004..1266 -> 262-tiles track
# Epsilon decay steps ----> 11629
# 322 -3.680076628352545 35
# Track generation: 1183..1483 -> 300-tiles track
# Epsilon decay steps ----> 11664
# 323 20.700668896320884 65
# Track generation: 1147..1437 -> 290-tiles track
# Epsilon decay steps ----> 11729
# 324 -4.178546712802817 28
# Track generation: 1247..1562 -> 315-tiles track
# Epsilon decay steps ----> 11757
# 325 -3.822292993630626 31
# Track generation: 1316..1649 -> 333-tiles track
# Epsilon decay steps ----> 11788
# 326 4.204819277108243 90
# Track generation: 1031..1296 -> 265-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1074..1346 -> 272-tiles track
# Epsilon decay steps ----> 11878
# 327 -1.1896678966790226 48
# Track generation: 1100..1379 -> 279-tiles track
# Epsilon decay steps ----> 11926
# 328 -6.517266187050355 27
# Track generation: 1186..1487 -> 301-tiles track
# Epsilon decay steps ----> 11953
# 329 -5.966666666666667 31
# Track generation: 999..1253 -> 254-tiles track
# Epsilon decay steps ----> 11984
# 330 -2.5320158102767287 34
# Track generation: 1075..1348 -> 273-tiles track
# Epsilon decay steps ----> 12018
# 331 2.9647058823528774 46
# Track generation: 1136..1424 -> 288-tiles track
# Epsilon decay steps ----> 12064
# 332 -4.009756097561038 28
# Track generation: 1203..1508 -> 305-tiles track
# Epsilon decay steps ----> 12092
# 333 9.56315789473674 44
# Track generation: 1161..1456 -> 295-tiles track
# Epsilon decay steps ----> 12136
# 334 6.61496598639447 36
# Track generation: 1050..1321 -> 271-tiles track
# Epsilon decay steps ----> 12172
# 335 11.844444444444342 42
# Track generation: 1199..1503 -> 304-tiles track
# Epsilon decay steps ----> 12214
# 336 -9.497689768976851 42
# Track generation: 1243..1558 -> 315-tiles track
# Epsilon decay steps ----> 12256
# 337 5.316560509554066 43
# Track generation: 1231..1543 -> 312-tiles track
# Epsilon decay steps ----> 12299
# 338 -1.345659163987193 45
# Track generation: 1283..1608 -> 325-tiles track
# Epsilon decay steps ----> 12344
# 339 -8.895061728395024 35
# Track generation: 1125..1410 -> 285-tiles track
# Epsilon decay steps ----> 12379
# 340 -4.052112676056389 29
# Track generation: 1068..1339 -> 271-tiles track
# Epsilon decay steps ----> 12408
# 341 -3.6740740740741344 32
# Track generation: 1103..1383 -> 280-tiles track
# Epsilon decay steps ----> 12440
# 342 32.48458781361988 64
# Track generation: 1254..1571 -> 317-tiles track
# Epsilon decay steps ----> 12504
# 343 -11.977215189873387 26
# Track generation: 1183..1483 -> 300-tiles track
# Epsilon decay steps ----> 12530
# 344 33.73411371237442 55
# Track generation: 1115..1398 -> 283-tiles track
# Epsilon decay steps ----> 12585
# 345 -6.277304964538999 37
# Track generation: 1235..1548 -> 313-tiles track
# Epsilon decay steps ----> 12622
# 346 15.176923076922982 43
# Track generation: 1071..1351 -> 280-tiles track
# Epsilon decay steps ----> 12665
# 347 14.57921146953396 52
# Track generation: 1004..1259 -> 255-tiles track
# Epsilon decay steps ----> 12717
# 348 -7.514960629921239 24
# Track generation: 1191..1493 -> 302-tiles track
# Epsilon decay steps ----> 12741
# 349 -8.166445182724223 27
# Track generation: 1215..1522 -> 307-tiles track
# Epsilon decay steps ----> 12768
# 350 -5.2241830065359665 27
# Track generation: 1218..1483 -> 265-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1153..1445 -> 292-tiles track
# Epsilon decay steps ----> 12795
# 351 23.855670103092656 60
# Track generation: 1076..1354 -> 278-tiles track
# Epsilon decay steps ----> 12855
# 352 -6.139350180505419 26
# Track generation: 1111..1393 -> 282-tiles track
# Epsilon decay steps ----> 12881
# 353 17.5220640569394 41
# Track generation: 1069..1347 -> 278-tiles track
# Epsilon decay steps ----> 12922
# 354 -2.809025270758177 51
# Track generation: 1020..1279 -> 259-tiles track
# Epsilon decay steps ----> 12973
# 355 41.01937984496115 55
# Track generation: 1104..1392 -> 288-tiles track
# Epsilon decay steps ----> 13028
# 356 10.896167247386636 48
# Track generation: 1155..1448 -> 293-tiles track
# Epsilon decay steps ----> 13076
# 357 9.820547945205362 49
# Track generation: 1217..1525 -> 308-tiles track
# Epsilon decay steps ----> 13125
# 358 -9.756026058631887 31
# Track generation: 1285..1610 -> 325-tiles track
# Epsilon decay steps ----> 13156
# 359 -9.581481481481452 27
# Track generation: 1103..1383 -> 280-tiles track
# Epsilon decay steps ----> 13183
# 360 0.842293906809946 50
# Track generation: 1153..1448 -> 295-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1126..1419 -> 293-tiles track
# Epsilon decay steps ----> 13233
# 361 22.919178082191657 51
# Track generation: 1085..1360 -> 275-tiles track
# Epsilon decay steps ----> 13284
# 362 3.896350364963425 42
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 13326
# 363 -5.377304964539027 34
# Track generation: 1228..1539 -> 311-tiles track
# Epsilon decay steps ----> 13360
# 364 -6.419354838709673 30
# Track generation: 1206..1512 -> 306-tiles track
# Epsilon decay steps ----> 13390
# 365 -8.127868852458986 26
# Track generation: 1108..1389 -> 281-tiles track
# Epsilon decay steps ----> 13416
# 366 -0.7285714285714882 31
# Track generation: 1110..1392 -> 282-tiles track
# Epsilon decay steps ----> 13447
# 367 5.08718861209956 35
# Track generation: 1148..1409 -> 261-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 13482
# 368 -5.244147157190657 40
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 13522
# 369 20.311705685618627 44
# Track generation: 1224..1534 -> 310-tiles track
# Epsilon decay steps ----> 13566
# 370 0.9624595469254942 38
# Track generation: 1154..1446 -> 292-tiles track
# Epsilon decay steps ----> 13604
# 371 -3.6085910652921456 37
# Track generation: 1072..1344 -> 272-tiles track
# Epsilon decay steps ----> 13641
# 372 -6.259778597785974 28
# Track generation: 1033..1296 -> 263-tiles track
# Epsilon decay steps ----> 13669
# 373 -2.582442748091662 31
# Track generation: 1199..1503 -> 304-tiles track
# Epsilon decay steps ----> 13700
# 374 1.603300330032944 38
# Track generation: 1151..1443 -> 292-tiles track
# Epsilon decay steps ----> 13738
# 375 29.692096219931123 52
# Track generation: 1027..1288 -> 261-tiles track
# Epsilon decay steps ----> 13790
# 376 12.107692307692218 34
# Track generation: 1027..1293 -> 266-tiles track
# Epsilon decay steps ----> 13824
# 377 12.683018867924432 42
# Track generation: 978..1237 -> 259-tiles track
# Epsilon decay steps ----> 13866
# 378 16.887596899224697 45
# Track generation: 1072..1348 -> 276-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1192..1494 -> 302-tiles track
# Epsilon decay steps ----> 13911
# 379 -1.799667774086437 39
# Track generation: 1220..1529 -> 309-tiles track
# Epsilon decay steps ----> 13950
# 380 5.001298701298566 79
# Track generation: 995..1256 -> 261-tiles track
# Epsilon decay steps ----> 14029
# 381 -7.423076923076895 35
# Track generation: 1196..1499 -> 303-tiles track
# Epsilon decay steps ----> 14064
# 382 14.057615894039628 41
# Track generation: 1294..1622 -> 328-tiles track
# Epsilon decay steps ----> 14105
# 383 -6.035168195718658 35
# Track generation: 1076..1349 -> 273-tiles track
# Epsilon decay steps ----> 14140
# 384 0.11176470588229037 31
# Track generation: 1129..1415 -> 286-tiles track
# Epsilon decay steps ----> 14171
# 385 31.66666666666653 50
# Track generation: 1320..1654 -> 334-tiles track
# Epsilon decay steps ----> 14221
# 386 8.542042042041956 45
# Track generation: 1248..1564 -> 316-tiles track
# Epsilon decay steps ----> 14266
# 387 -6.777777777777766 30
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 14296
# 388 0.6685314685313983 36
# Track generation: 987..1244 -> 257-tiles track
# Epsilon decay steps ----> 14332
# 389 -1.0562500000000696 28
# Track generation: 1130..1416 -> 286-tiles track
# Epsilon decay steps ----> 14360
# 390 -9.656140350877166 24
# Track generation: 1060..1329 -> 269-tiles track
# Epsilon decay steps ----> 14384
# 391 3.9820895522387296 32
# Track generation: 989..1249 -> 260-tiles track
# Epsilon decay steps ----> 14416
# 392 2.4490347490346913 41
# Track generation: 1291..1618 -> 327-tiles track
# Epsilon decay steps ----> 14457
# 393 -9.02760736196315 35
# Track generation: 1008..1264 -> 256-tiles track
# Epsilon decay steps ----> 14492
# 394 12.637254901960702 35
# Track generation: 1187..1488 -> 301-tiles track
# Epsilon decay steps ----> 14527
# 395 -5.066666666666691 28
# Track generation: 1106..1387 -> 281-tiles track
# Epsilon decay steps ----> 14555
# 396 -6.9714285714285555 28
# Track generation: 1029..1295 -> 266-tiles track
# Epsilon decay steps ----> 14583
# 397 -2.884905660377413 31
# Track generation: 1068..1342 -> 274-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1148..1444 -> 296-tiles track
# Epsilon decay steps ----> 14614
# 398 16.53728813559308 59
# Track generation: 1132..1427 -> 295-tiles track
# Epsilon decay steps ----> 14673
# 399 29.72721088435356 61
# Track generation: 1246..1562 -> 316-tiles track
# Epsilon decay steps ----> 14734
# 400 28.366666666666497 61
# Track generation: 1142..1439 -> 297-tiles track
# Epsilon decay steps ----> 14795
# 401 -2.872972972973024 33
# Track generation: 1239..1553 -> 314-tiles track
# Epsilon decay steps ----> 14828
# 402 2.0488817891373223 33
# Track generation: 1078..1352 -> 274-tiles track
# Epsilon decay steps ----> 14861
# 403 41.62307692307692 51
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 14912
# 404 -4.4773049645390515 31
# Track generation: 1160..1454 -> 294-tiles track
# Epsilon decay steps ----> 14943
# 405 10.794539249146673 68
# Track generation: 1120..1404 -> 284-tiles track
# Epsilon decay steps ----> 15011
# 406 46.205653710247475 62
# Track generation: 1279..1605 -> 326-tiles track
# Epsilon decay steps ----> 15073
# 407 -5.284615384615407 33
# Track generation: 1182..1482 -> 300-tiles track
# Epsilon decay steps ----> 15106
# 408 -4.988628762541838 28
# Track generation: 1051..1326 -> 275-tiles track
# Epsilon decay steps ----> 15134
# 409 38.94233576642318 59
# Track generation: 1201..1505 -> 304-tiles track
# Epsilon decay steps ----> 15193
# 410 -5.597689768976908 29
# Track generation: 1292..1620 -> 328-tiles track
# Epsilon decay steps ----> 15222
# 411 5.655351681957118 47
# Track generation: 1036..1299 -> 263-tiles track
# Epsilon decay steps ----> 15269
# 412 16.1183206106869 45
# Track generation: 1036..1303 -> 267-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1320..1662 -> 342-tiles track
# Epsilon decay steps ----> 15314
# 413 11.320821114369423 52
# Track generation: 1142..1431 -> 289-tiles track
# Epsilon decay steps ----> 15366
# 414 0.7499999999999183 35
# Track generation: 1011..1274 -> 263-tiles track
# Epsilon decay steps ----> 15401
# 415 11.1847328244274 36
# Track generation: 1208..1524 -> 316-tiles track
# Epsilon decay steps ----> 15437
# 416 20.942857142857 54
# Track generation: 1039..1303 -> 264-tiles track
# Epsilon decay steps ----> 15491
# 417 8.925095057034135 43
# Track generation: 1120..1404 -> 284-tiles track
# Epsilon decay steps ----> 15534
# 418 -7.198586572438147 28
# Track generation: 1067..1345 -> 278-tiles track
# Epsilon decay steps ----> 15562
# 419 26.071841155234523 51
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 15613
# 420 -0.6312056737589309 30
# Track generation: 1140..1429 -> 289-tiles track
# Epsilon decay steps ----> 15643
# 421 16.311111111110996 41
# Track generation: 985..1243 -> 258-tiles track
# Epsilon decay steps ----> 15684
# 422 2.7194552529181912 41
# Track generation: 1103..1383 -> 280-tiles track
# Epsilon decay steps ----> 15725
# 423 38.1688172043009 57
# Track generation: 1237..1550 -> 313-tiles track
# Epsilon decay steps ----> 15782
# 424 22.29743589743572 62
# Track generation: 1132..1419 -> 287-tiles track
# Epsilon decay steps ----> 15844
# 425 9.35804195804186 42
# ...
# 1583 31.080281690140758 41
# Track generation: 1124..1409 -> 285-tiles track
# Epsilon decay steps ----> 62992
# 1584 18.495774647887245 36
# Track generation: 1179..1478 -> 299-tiles track
# Epsilon decay steps ----> 63028
# 1585 15.579865771811988 38
# Track generation: 1186..1486 -> 300-tiles track
# Epsilon decay steps ----> 63066
# 1586 37.33411371237447 43
# Track generation: 1335..1673 -> 338-tiles track
# Epsilon decay steps ----> 63109
# 1587 2.1409495548960784 35
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 63144
# 1588 -2.2729729729730295 31
# Track generation: 999..1257 -> 258-tiles track
# Epsilon decay steps ----> 63175
# 1589 12.601556420233372 34
# Track generation: 1091..1374 -> 283-tiles track
# Epsilon decay steps ----> 63209
# 1590 15.599290780141757 35
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 63244
# 1591 26.268085106382742 94
# Track generation: 986..1241 -> 255-tiles track
# Epsilon decay steps ----> 63338
# 1592 5.833070866141657 32
# Track generation: 1269..1590 -> 321-tiles track
# Epsilon decay steps ----> 63370
# 1593 3.874999999999929 35
# Track generation: 1173..1470 -> 297-tiles track
# Epsilon decay steps ----> 63405
# 1594 12.818918918918833 37
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 63442
# 1595 19.969863013698536 38
# Track generation: 1217..1526 -> 309-tiles track
# Epsilon decay steps ----> 63480
# 1596 2.5675324675324056 33
# Track generation: 1241..1556 -> 315-tiles track
# Epsilon decay steps ----> 63513
# 1597 16.07070063694259 39
# Track generation: 1063..1333 -> 270-tiles track
# Epsilon decay steps ----> 63552
# 1598 44.56691449814146 45
# Track generation: 1225..1535 -> 310-tiles track
# Epsilon decay steps ----> 63597
# 1599 4.498705501618055 37
# Track generation: 1087..1370 -> 283-tiles track
# Epsilon decay steps ----> 63634
# 1600 14.645390070921906 50
# Track generation: 1195..1497 -> 302-tiles track
# Epsilon decay steps ----> 63684
# 1601 30.522923588039752 42
# Track generation: 1245..1560 -> 315-tiles track
# Epsilon decay steps ----> 63726
# 1602 28.209554140127295 41
# Track generation: 1104..1384 -> 280-tiles track
# Epsilon decay steps ----> 63767
# 1603 22.663440860214955 37
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 63804
# 1604 37.57543859649111 42
# Track generation: 1173..1475 -> 302-tiles track
# Epsilon decay steps ----> 63846
# 1605 30.82292358803975 41
# Track generation: 1127..1413 -> 286-tiles track
# Epsilon decay steps ----> 63887
# 1606 47.5017543859651 44
# Track generation: 1061..1330 -> 269-tiles track
# Epsilon decay steps ----> 63931
# 1607 48.28955223880621 46
# Track generation: 1184..1484 -> 300-tiles track
# Epsilon decay steps ----> 63977
# 1608 49.51204013377951 47
# Track generation: 1225..1545 -> 320-tiles track
# Epsilon decay steps ----> 64024
# 1609 12.487147335423117 38
# Track generation: 1002..1257 -> 255-tiles track
# Epsilon decay steps ----> 64062
# 1610 79.77322834645699 48
# Track generation: 1172..1469 -> 297-tiles track
# Epsilon decay steps ----> 64110
# 1611 13.118918918918837 36
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 64146
# 1612 11.663157894736763 37
# Track generation: 1115..1398 -> 283-tiles track
# Epsilon decay steps ----> 64183
# 1613 8.80709219858148 34
# Track generation: 1192..1494 -> 302-tiles track
# Epsilon decay steps ----> 64217
# 1614 76.75681063122956 54
# Track generation: 942..1186 -> 244-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1259..1578 -> 319-tiles track
# Epsilon decay steps ----> 64271
# 1615 7.235849056603705 35
# Track generation: 1076..1352 -> 276-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1324..1659 -> 335-tiles track
# Epsilon decay steps ----> 64306
# 1616 3.0341317365268807 33
# Track generation: 1059..1328 -> 269-tiles track
# Epsilon decay steps ----> 64339
# 1617 38.2955223880596 42
# Track generation: 995..1248 -> 253-tiles track
# Epsilon decay steps ----> 64381
# 1618 19.12380952380944 68
# Track generation: 1195..1498 -> 303-tiles track
# Epsilon decay steps ----> 64449
# 1619 6.223841059602563 34
# Track generation: 1222..1540 -> 318-tiles track
# Epsilon decay steps ----> 64483
# 1620 26.900630914826365 75
# Track generation: 1133..1420 -> 287-tiles track
# Epsilon decay steps ----> 64558
# 1621 13.051048951048884 53
# Track generation: 1031..1293 -> 262-tiles track
# Epsilon decay steps ----> 64611
# 1622 4.882758620689589 32
# Track generation: 1253..1570 -> 317-tiles track
# Epsilon decay steps ----> 64643
# 1623 4.610126582278408 34
# Track generation: 1197..1501 -> 304-tiles track
# Epsilon decay steps ----> 64677
# 1624 11.804290429042815 37
# Track generation: 1120..1406 -> 286-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1171..1468 -> 297-tiles track
# Epsilon decay steps ----> 64714
# 1625 10.040540540540462 35
# Track generation: 1068..1339 -> 271-tiles track
# Epsilon decay steps ----> 64749
# 1626 27.859259259259147 38
# Track generation: 1089..1371 -> 282-tiles track
# Epsilon decay steps ----> 64787
# 1627 5.687188612099572 33
# Track generation: 1176..1474 -> 298-tiles track
# Epsilon decay steps ----> 64820
# 1628 9.90404040404033 35
# Track generation: 1301..1630 -> 329-tiles track
# Epsilon decay steps ----> 64855
# 1629 6.085365853658459 35
# Track generation: 1195..1498 -> 303-tiles track
# Epsilon decay steps ----> 64890
# 1630 0.5013245033111886 31
# Track generation: 1220..1529 -> 309-tiles track
# Epsilon decay steps ----> 64921
# 1631 -8.125974025973973 47
# Track generation: 1136..1424 -> 288-tiles track
# Epsilon decay steps ----> 64968
# 1632 -14.947038327526112 18
# Track generation: 1141..1431 -> 290-tiles track
# Epsilon decay steps ----> 64986
# 1633 -6.258131487889241 58
# Track generation: 1095..1373 -> 278-tiles track
# Epsilon decay steps ----> 65044
# 1634 13.14151624548731 58
# Track generation: 1139..1428 -> 289-tiles track
# Epsilon decay steps ----> 65102
# 1635 7.39444444444436 36
# Track generation: 1196..1499 -> 303-tiles track
# Epsilon decay steps ----> 65138
# 1636 30.613907284768082 41
# Track generation: 1121..1405 -> 284-tiles track
# Epsilon decay steps ----> 65179
# 1637 8.669257950529953 34
# Track generation: 1179..1478 -> 299-tiles track
# Epsilon decay steps ----> 65213
# 1638 61.41543624161106 53
# Track generation: 1055..1326 -> 271-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1097..1375 -> 278-tiles track
# Epsilon decay steps ----> 65266
# 1639 9.511191335740001 34
# Track generation: 1122..1407 -> 285-tiles track
# Epsilon decay steps ----> 65300
# 1640 41.64366197183102 41
# Track generation: 1060..1329 -> 269-tiles track
# Epsilon decay steps ----> 65341
# 1641 18.00746268656708 35
# Track generation: 1272..1594 -> 322-tiles track
# Epsilon decay steps ----> 65376
# 1642 38.15109034267904 45
# Track generation: 960..1207 -> 247-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1272..1594 -> 322-tiles track
# Epsilon decay steps ----> 65421
# 1643 20.174766355140044 53
# Track generation: 1099..1378 -> 279-tiles track
# Epsilon decay steps ----> 65474
# 1644 19.856834532374016 47
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 65521
# 1645 35.8931506849314 42
# Track generation: 1252..1569 -> 317-tiles track
# Epsilon decay steps ----> 65563
# 1646 10.832911392405009 66
# Track generation: 1299..1628 -> 329-tiles track
# Epsilon decay steps ----> 65629
# 1647 25.326829268292563 42
# Track generation: 1236..1549 -> 313-tiles track
# Epsilon decay steps ----> 65671
# 1648 22.787179487179387 39
# Track generation: 1013..1279 -> 266-tiles track
# Epsilon decay steps ----> 65710
# 1649 18.25660377358482 36
# Track generation: 1303..1633 -> 330-tiles track
# Epsilon decay steps ----> 65746
# 1650 2.6346504559269732 36
# Track generation: 1028..1289 -> 261-tiles track
# Epsilon decay steps ----> 65782
# 1651 19.199999999999918 36
# Track generation: 1316..1658 -> 342-tiles track
# Epsilon decay steps ----> 65818
# 1652 7.4882697947212655 55
# Track generation: 1200..1504 -> 304-tiles track
# Epsilon decay steps ----> 65873
# 1653 14.804620462046103 38
# Track generation: 1164..1459 -> 295-tiles track
# Epsilon decay steps ----> 65911
# 1654 18.62721088435348 98
# Track generation: 1151..1444 -> 293-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1229..1540 -> 311-tiles track
# Epsilon decay steps ----> 66009
# 1655 5.58387096774187 33
# Track generation: 1187..1488 -> 301-tiles track
# Epsilon decay steps ----> 66042
# 1656 -2.033333333333392 29
# Track generation: 1343..1683 -> 340-tiles track
# Epsilon decay steps ----> 66071
# 1657 5.198230088495492 34
# Track generation: 1191..1493 -> 302-tiles track
# Epsilon decay steps ----> 66105
# 1658 -3.0219269102990616 32
# Track generation: 1140..1429 -> 289-tiles track
# Epsilon decay steps ----> 66137
# 1659 30.19999999999989 41
# Track generation: 1157..1451 -> 294-tiles track
# Epsilon decay steps ----> 66178
# 1660 32.24641638225246 42
# Track generation: 1204..1509 -> 305-tiles track
# Epsilon decay steps ----> 66220
# 1661 35.27894736842095 46
# Track generation: 1094..1377 -> 283-tiles track
# Epsilon decay steps ----> 66266
# 1662 28.2836879432623 40
# Track generation: 1127..1413 -> 286-tiles track
# Epsilon decay steps ----> 66306
# 1663 27.349122807017444 41
# Track generation: 1243..1558 -> 315-tiles track
# Epsilon decay steps ----> 66347
# 1664 10.855414012738713 67
# Track generation: 1211..1518 -> 307-tiles track
# Epsilon decay steps ----> 66414
# 1665 48.76732026143816 54
# Track generation: 1031..1293 -> 262-tiles track
# Epsilon decay steps ----> 66468
# 1666 38.096934865900245 49
# Track generation: 1159..1453 -> 294-tiles track
# Epsilon decay steps ----> 66517
# 1667 10.455631399317326 35
# Track generation: 1248..1564 -> 316-tiles track
# Epsilon decay steps ----> 66552
# 1668 23.94285714285705 44
# Track generation: 1162..1457 -> 295-tiles track
# Epsilon decay steps ----> 66596
# 1669 19.620408163265218 38
# Track generation: 1064..1334 -> 270-tiles track
# Epsilon decay steps ----> 66634
# 1670 10.092193308550108 36
# Track generation: 1275..1597 -> 322-tiles track
# Epsilon decay steps ----> 66670
# 1671 12.513707165108947 37
# Track generation: 1261..1580 -> 319-tiles track
# Epsilon decay steps ----> 66707
# 1672 -6.387421383647796 28
# Track generation: 1155..1448 -> 293-tiles track
# Epsilon decay steps ----> 66735
# 1673 37.64246575342456 59
# Track generation: 1223..1533 -> 310-tiles track
# Epsilon decay steps ----> 66794
# 1674 46.80614886731412 47
# Track generation: 1156..1449 -> 293-tiles track
# Epsilon decay steps ----> 66841
# 1675 10.595890410958816 35
# Track generation: 1159..1453 -> 294-tiles track
# Epsilon decay steps ----> 66876
# 1676 10.755631399317323 34
# Track generation: 1157..1454 -> 297-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1126..1411 -> 285-tiles track
# Epsilon decay steps ----> 66910
# 1677 14.974647887323862 36
# Track generation: 1079..1358 -> 279-tiles track
# Epsilon decay steps ----> 66946
# 1678 9.068345323740921 35
# Track generation: 1232..1544 -> 312-tiles track
# Epsilon decay steps ----> 66981
# 1679 8.085209003215368 35
# Track generation: 1176..1474 -> 298-tiles track
# Epsilon decay steps ----> 67016
# 1680 30.473063973063873 45
# Track generation: 1162..1456 -> 294-tiles track
# Epsilon decay steps ----> 67061
# 1681 13.568600682593775 36
# Track generation: 1195..1497 -> 302-tiles track
# Epsilon decay steps ----> 67097
# 1682 9.667109634551416 34
# Track generation: 1109..1390 -> 281-tiles track
# Epsilon decay steps ----> 67131
# 1683 78.38571428571458 53
# Track generation: 1124..1409 -> 285-tiles track
# Epsilon decay steps ----> 67184
# 1684 -6.530985915492932 49
# Track generation: 1077..1356 -> 279-tiles track
# Epsilon decay steps ----> 67233
# 1685 18.353956834532312 64
# Track generation: 1191..1493 -> 302-tiles track
# Epsilon decay steps ----> 67297
# 1686 39.63421926910276 67
# Track generation: 1061..1330 -> 269-tiles track
# Epsilon decay steps ----> 67364
# 1687 24.870149253731256 37
# Track generation: 1170..1466 -> 296-tiles track
# Epsilon decay steps ----> 67401
# 1688 4.298305084745678 32
# Track generation: 1368..1714 -> 346-tiles track
# Epsilon decay steps ----> 67433
# 1689 -0.614492753623253 32
# Track generation: 1149..1440 -> 291-tiles track
# Epsilon decay steps ----> 67465
# 1690 10.579310344827505 36
# Track generation: 1085..1366 -> 281-tiles track
# Epsilon decay steps ----> 67501
# 1691 55.48571428571452 46
# Track generation: 1172..1469 -> 297-tiles track
# Epsilon decay steps ----> 67547
# 1692 9.740540540540472 36
# Track generation: 1157..1458 -> 301-tiles track
# Epsilon decay steps ----> 67583
# 1693 6.46666666666658 34
# Track generation: 1053..1325 -> 272-tiles track
# Epsilon decay steps ----> 67617
# 1694 7.000369003689965 33
# Track generation: 1090..1374 -> 284-tiles track
# Epsilon decay steps ----> 67650
# 1695 8.103533568904531 83
# Track generation: 1116..1399 -> 283-tiles track
# Epsilon decay steps ----> 67733
# 1696 33.275886524822575 47
# Track generation: 1114..1397 -> 283-tiles track
# Epsilon decay steps ----> 67780
# 1697 25.33758865248216 38
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 67818
# 1698 40.784210526315725 43
# Track generation: 1056..1324 -> 268-tiles track
# Epsilon decay steps ----> 67861
# 1699 39.16104868913847 40
# Track generation: 1255..1573 -> 318-tiles track
# Epsilon decay steps ----> 67901
# 1700 -1.208832807571035 32
# Track generation: 1230..1542 -> 312-tiles track
# Epsilon decay steps ----> 67933
# 1701 25.877813504823074 40
# Track generation: 1179..1478 -> 299-tiles track
# Epsilon decay steps ----> 67973
# 1702 -2.4543624161074327 31
# Track generation: 1111..1393 -> 282-tiles track
# Epsilon decay steps ----> 68004
# 1703 20.78078291814937 42
# Track generation: 1144..1434 -> 290-tiles track
# Epsilon decay steps ----> 68046
# 1704 1.5418685121106641 32
# Track generation: 1145..1435 -> 290-tiles track
# Epsilon decay steps ----> 68078
# 1705 7.862283737024153 34
# Track generation: 1363..1718 -> 355-tiles track
# Epsilon decay steps ----> 68112
# 1706 18.847457627118544 40
# Track generation: 1192..1494 -> 302-tiles track
# Epsilon decay steps ----> 68152
# 1707 48.65647840531578 48
# Track generation: 1296..1629 -> 333-tiles track
# Epsilon decay steps ----> 68200
# 1708 11.068674698795085 37
# Track generation: 1177..1478 -> 301-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 68237
# 1709 8.696491228070094 33
# Track generation: 1218..1526 -> 308-tiles track
# Epsilon decay steps ----> 68270
# 1710 29.289250814332135 42
# Track generation: 937..1178 -> 241-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 967..1213 -> 246-tiles track
# Epsilon decay steps ----> 68312
# 1711 10.616326530612163 34
# Track generation: 1081..1359 -> 278-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1274..1606 -> 332-tiles track
# Epsilon decay steps ----> 68346
# 1712 -2.409667673716072 32
# Track generation: 1108..1389 -> 281-tiles track
# Epsilon decay steps ----> 68378
# 1713 -17.057142857142846 14
# Track generation: 1129..1421 -> 292-tiles track
# Epsilon decay steps ----> 68392
# 1714 -0.9628865979382226 74
# Track generation: 1205..1509 -> 304-tiles track
# Epsilon decay steps ----> 68466
# 1715 -5.2973597359736075 39
# Track generation: 1267..1588 -> 321-tiles track
# Epsilon decay steps ----> 68505
# 1716 23.949999999999896 41
# Track generation: 1170..1467 -> 297-tiles track
# Epsilon decay steps ----> 68546
# 1717 1.1054054054053424 31
# Track generation: 1128..1414 -> 286-tiles track
# Epsilon decay steps ----> 68577
# 1718 14.814035087719212 36
# Track generation: 999..1258 -> 259-tiles track
# Epsilon decay steps ----> 68613
# 1719 8.55968992248053 34
# Track generation: 1411..1768 -> 357-tiles track
# Epsilon decay steps ----> 68647
# 1720 23.279775280898775 43
# Track generation: 1191..1493 -> 302-tiles track
# Epsilon decay steps ----> 68690
# 1721 13.61162790697663 43
# Track generation: 1143..1437 -> 294-tiles track
# Epsilon decay steps ----> 68733
