# %%
The agent performed relatively well and played the game better than what a human can possibly learn in the same amount of time
Can be optimized further by changing the network structure and tuning the hyperparameters hence reducing the cost of training
Algorithm can be generalized even more such that it be applied to any environment
import matplotlib.pyplot as plt
import pandas as pd

rewards = pd.read_csv('rewards.csv', header=None)
frames = pd.read_csv('frames.csv', header=None)

# %%
plt.plot(rewards[::10])

# %%
r = rewards[0].tolist()
max_r = []
for i in range(int(len(rewards)/10)):
    max_r.append(max(r[i*10:i*10+10]))
    
plt.clf()
plt.plot(max_r)

# %%
r = rewards[0].tolist()
max(r)
# Out:
# 935.1999999999886
